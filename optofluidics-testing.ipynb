# %%
from pre_proc import Datafile, Dataset
from reaction import Reaction
from standard_functions import *
from lmfit import minimize, Parameters
file_path=r'2019-11-06.h5'
df1=Datafile(file_path)
df1.list_groups()
ds1=Dataset(df1)
ds1.pre_process()
ds1.calculate_abs()
# Out:
# datafile intialised successfully
#
# Key 0: 06112019_MV-aCDs-EDTApH6_Scan1
#
# /06112019_MV-aCDs-EDTApH6_Scan1/timelapse_0 dataset loaded successfully
#
# measurement was started at 2019-11-06 15:56:30.868000,
#  normalising times and applying a background correction
#
# measurement contains 9625 spectra with 1044 wavelengths
# C:\Users\tl457\OneDrive - University Of Cambridge 1\Optofluidics Python Package\pre_proc.py:229: RuntimeWarning: divide by zero encountered in log10
#   abs=-np.log10(self.pre_proc_data.div(self.ref_spectra_arr))
# C:\Users\tl457\OneDrive - University Of Cambridge 1\Optofluidics Python Package\pre_proc.py:229: RuntimeWarning: invalid value encountered in log10
#   abs=-np.log10(self.pre_proc_data.div(self.ref_spectra_arr))
#           191.525217  192.321910  193.118546  193.915127  194.711650  \
# 0.000      -0.602060         NaN    0.301030    0.221849   -0.041393
# 0.919      -0.602060         inf   -0.301030    0.397940   -0.041393
# ...

# %%
c1=Reaction(ds1,600,13600,5)
c1.calculate_conc(5)
c1.linear_drift([2790,5750,8650])
# Out:
# Calculating concentration using range 597.50551777423 nm to 602.8476550090985 nm.
# 0.000       0.180286
# 0.919       0.164001
# 1.839       0.168650
# 2.759       0.173555
# 3.679       0.168425
#               ...
# 8878.342   -0.149948
# 8879.263   -0.126764
# 8880.182   -0.120874
# 8881.102   -0.136043
# 8882.020   -0.151586
# Length: 9625, dtype: float64

# %%
from reaction import Reaction
times_arr=c1.find_turn_points(0.015,translate=60,plot=False)

params = Parameters()
params.add('t_erf', value = 413)
params.add('kc', value = 0.01, vary = False)
params.add('kbr', value = 0.000457)
params.add('k', value = 0.00980)
params.add('kr', value = 0.00369)
params.add('o', value = 68)
params.add('c0', value = 40, vary = False)
params.add('K', value = 0.786, vary = False)
params.add('end', value = 9000, vary = False)

model=c1.create_model(params)
residual=c1.residual(params)
# Out:
# 3.0 cycles detected

# %%
out=c1.fit_model(params)
compare_model(c1)
# Out:
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 25
#     # data points      = 9625
#     # variables        = 5
#     chi-square         = 3019.56569
#     reduced chi-square = 0.31388417
#     Akaike info crit   = -11147.7896
#     Bayesian info crit = -11111.9290
# ##  Warning: uncertainties could not be estimated:
#     t_erf:  at initial value
#     o:      at initial value
# [[Variables]]
#     t_erf:  413.000000 (init = 413)
#     kc:     0.01 (fixed)
#     kbr:    4.5276e-04 (init = 0.000457)
#     k:      0.00848745 (init = 0.0098)
#     kr:     0.00326175 (init = 0.00369)
#     o:      68.0000000 (init = 68)
#     c0:     40 (fixed)
#     K:      0.786 (fixed)
#     end:    9000 (fixed)
