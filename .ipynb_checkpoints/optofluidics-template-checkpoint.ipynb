# %% [markdown]
# ![optofluidics.png](attachment:optofluidics.png)
#
# # Optofluidics Template
# This Jupyter Notebook is a template for using the Optofluidics module to process HDF5 spectroscopic data.

# %%
import optofluidics as of
from lmfit import Parameters
import matplotlib.pyplot as plt

# Set file path to datafile location, including the .h5 file extension.
file_path = r'C:\Users\tl457\OneDrive - University Of Cambridge 1\Measurements\Carbon Dots - Absorption\Jupyter Temp\2019-11-06.h5'

# Set save path to the desired export location.
export_path = r'C:\Users\tl457\OneDrive - University Of Cambridge 1\Measurements\Carbon Dots - Absorption\Exports'

# %% [markdown]
# ## Load Datafile
# Load the desired datafile and list the datasets contained within.

# %%
# Load the datafile and create a Datafile instance
df1=of.Datafile(file_path)

# List the datasets contained within the datafile
df1.list_groups()
# Out:
# Datafile intialised successfully
#
# Key 0: 06112019_MV-aCDs-EDTApH6_Scan1

# %% [markdown]
# ## Pre-Processing
# Create a Dataset instance, pre-process the data to calculate elapsed time and background correct, then calculate the absorbances using the stored reference spectra.

# %%
# Create a Dataset instance (default is key 0 and timelapse 0 for the datafile specified)
ds1=of.Dataset(df1,0,0)

# Pre-process the data and calculate the absorbances
ds1.pre_process()
ds1.calculate_abs()
# Out:
# /06112019_MV-aCDs-EDTApH6_Scan1/timelapse_0 dataset loaded successfully
#
# Measurement was started at 2019-11-06 15:56:30.868000,
#  normalising times and applying a background correction
#
# Measurement contains 9625 spectra with 1044 wavelengths
#
# Elapsed time for pre-processing: 25.5424722
# C:\Users\tl457\Documents\GitHub\optofluidics\optofluidics\pre_proc.py:235: RuntimeWarning: divide by zero encountered in log10
#   abs=-np.log10(self.pre_proc_data.div(self.ref_spectra_arr))
# C:\Users\tl457\Documents\GitHub\optofluidics\optofluidics\pre_proc.py:235: RuntimeWarning: invalid value encountered in log10
#   abs=-np.log10(self.pre_proc_data.div(self.ref_spectra_arr))
#           191.525217  192.321910  193.118546  193.915127  194.711650  \
# 0.000      -0.602060         NaN    0.301030    0.221849   -0.041393
# 0.919      -0.602060         inf   -0.301030    0.397940   -0.041393
# 1.839      -0.477121   -0.477121   -0.000000    0.698970   -0.079181
# 2.759      -0.477121   -0.477121    0.301030    0.397940   -0.113943
# 3.679      -0.778151   -0.301030   -0.176091    0.096910   -0.079181
# ...              ...         ...         ...         ...         ...
# 8878.342         inf   -0.477121   -0.176091    0.397940    0.096910
# 8879.263   -0.301030         inf   -0.176091    0.397940   -0.000000
# 8880.182   -0.301030   -0.477121    0.301030    0.221849    0.154902
# 8881.102   -0.000000   -0.000000   -0.000000    0.221849    0.154902
# 8882.020   -0.477121   -0.301030   -0.000000    0.221849   -0.041393
#
#           195.508118  196.304528  197.100882  197.897180  198.693421  ...  \
# 0.000       0.037789    0.032185   -0.000000   -0.087150   -0.062148  ...
# 0.919      -0.066947    0.032185   -0.000000   -0.045757   -0.032185  ...
# 1.839       0.037789    0.066947   -0.034762   -0.124939   -0.000000  ...
# 2.759      -0.034762    0.066947    0.037789   -0.000000    0.034762  ...
# 3.679      -0.034762    0.066947   -0.066947    0.051153   -0.000000  ...
# ...              ...         ...         ...         ...         ...  ...
# 8878.342    0.124939    0.146128   -0.000000   -0.000000    0.034762  ...
# 8879.263   -0.000000    0.104735   -0.034762   -0.045757    0.072551  ...
# 8880.182    0.124939    0.146128    0.037789   -0.000000    0.113943  ...
# 8881.102    0.037789   -0.000000    0.079181    0.109144    0.072551  ...
# 8882.020    0.176091    0.191886   -0.066947   -0.000000    0.113943  ...
#
#           979.760213  980.482831  981.205362  981.927806  982.650163  \
# 0.000      -0.000000   -0.104735   -0.151268   -0.057992    0.066947
# 0.919      -0.000000   -0.072551   -0.124939   -0.000000    0.066947
# 1.839       0.134699   -0.072551   -0.124939   -0.029963   -0.000000
# 2.759       0.062148   -0.000000   -0.066947   -0.029963    0.032185
# 3.679       0.062148   -0.000000   -0.096910    0.066947    0.032185
# ...              ...         ...         ...         ...         ...
# 8878.342    0.062148    0.041393   -0.034762    0.066947    0.191886
# 8879.263    0.062148    0.041393   -0.034762    0.066947    0.066947
# 8880.182    0.134699    0.041393   -0.096910   -0.000000    0.146128
# 8881.102    0.096910   -0.000000   -0.034762    0.146128    0.032185
# 8882.020   -0.000000   -0.072551   -0.034762    0.066947   -0.000000
#
#           983.372433  984.094617  984.816713  985.538722  986.260644
# 0.000       0.072551   -0.000000        -inf        -inf        -inf
# 0.919       0.072551   -0.000000         NaN         NaN         NaN
# 1.839       0.034762   -0.000000         NaN         NaN         NaN
# 2.759       0.034762    0.301030         NaN         NaN         NaN
# 3.679      -0.090177   -0.301030        -inf        -inf        -inf
# ...              ...         ...         ...         ...         ...
# 8878.342    0.159701   -0.000000         NaN         NaN         NaN
# 8879.263   -0.032185    0.301030         NaN         NaN         NaN
# 8880.182    0.034762   -0.000000         NaN         NaN         NaN
# 8881.102    0.072551   -0.176091         NaN         NaN         NaN
# 8882.020    0.034762   -0.000000         NaN         NaN         NaN
#
# [9625 rows x 1044 columns]

# %% [markdown]
# ## Processing
# Plot colourmap, calculate concentrations and apply a drift correction

# %%
# Plot colourmap
of.colourplot(ds1,[1000],[600],-0.5,1.5)
# Out:
# Will return 599.8 nm in dataset
# Will plot 1000.0 s in dataset

# %%
# Create Reaction instance
c1=of.Reaction(ds1,600,13600,5)

# Calculate concentrations
c1.calculate_conc(5)

# Apply a linear drift correction
c1.linear_drift([2790,5750,8650])

# Plot the concentration profile
c1.plot_conc()
# Out:
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.
# Calculating concentration using range 597.50551777423 nm to 602.8476550090985 nm.
# Absorbance will be averaged over 8 data points

# %%
# Find turning points to automatically detect the UV on/off times
# Ignore the first turning point in the plot as we manually specify in the find_turn_points function

times_arr=c1.find_turn_points(182,0.022,translate=60,plot=True)
print(c1.turning_points)
# Out:
# 3.0 cycles detected
# [ 182 1065 2878 4069 5881 7065]

# %% [markdown]
# ## Modelling
# Create an initial model then run a fitting algorithm to find the best parameters

# %%
# define initial model parameters ahead of fitting
params = Parameters()
params.add('t_erf', value = 231, min=0, max=500) #413
params.add('kc', value = 0.01, min=1e-5, max=0.1, vary = False) # raises NaN if value > 0.1
params.add('kbr', value = 0.000457, min=0.0001, max=0.1) #0.000457
params.add('k', value = 0.00980, min=0.0001, max=0.1) #0.00980
params.add('kr', value = 0.00369, min=0.0001, max=0.1) #0.00369
params.add('o', value = 68, min=10, max=100) #68
params.add('c0', value = 40, vary = False)
params.add('K', value = 0.786, vary = False) 
params.add('end', value = 9000, vary = False)

# create the model and plot
model=c1.create_model(params)
of.plot_model(c1)

# %%
# Run fitting algorithm (see lmfit documentation)
c1.fit_model(params,meth='leastsq')

# Plot a comparison of the experimental data to the model
of.compare_model(c1)
# Out:
# Elapsed time for fitting: 6.976364799999999
#
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 43
#     # data points      = 9625
#     # variables        = 5
#     chi-square         = 2236.20802
#     reduced chi-square = 0.23245406
#     Akaike info crit   = -14038.4796
#     Bayesian info crit = -14002.6190
# [[Variables]]
#     t_erf:  245.877244 +/- 0.67400458 (0.27%) (init = 231)
#     kc:     0.01 (fixed)
#     kbr:    4.7030e-04 +/- 9.3089e-07 (0.20%) (init = 0.000457)
#     k:      0.00913498 +/- 2.2643e-05 (0.25%) (init = 0.0098)
#     kr:     0.00331350 +/- 5.9555e-06 (0.18%) (init = 0.00369)
#     o:      82.8640935 +/- 1.05834337 (1.28%) (init = 68)
#     c0:     40 (fixed)
#     K:      0.786 (fixed)
#     end:    9000 (fixed)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(t_erf, o)   =  0.631
#     C(t_erf, k)   =  0.576
#     C(k, kr)      =  0.493
#     C(kbr, k)     =  0.438
#     C(t_erf, kbr) =  0.387
#     C(k, o)       =  0.341
#     C(kbr, kr)    = -0.266
#     C(kbr, o)     =  0.200
#     C(t_erf, kr)  =  0.172
#
#  The model attribute has been updated with these parameters.

# %%
rates = c1.get_rates()
plt.plot(rates['k(t)'])
plt.title('k(t)')
plt.xlim(100,1000);
plt.ylim(0,0.01);

# %%
# Export fitted model to csv file
c1.model2csv('2019-11-06-model.csv',export_path)
# Out:
# Model data saved to .csv succesfully.
